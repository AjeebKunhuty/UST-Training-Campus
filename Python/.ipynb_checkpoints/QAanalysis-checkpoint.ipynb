# %% [markdown]
# import pandas as pd
#
# studentsdf = pd.read_csv('Dataset/AWS_results.csv')
# answersdf = pd.read_csv('Dataset/AWS_answers.csv')
# studentsdf

# %%
answersdf
# Out:
#     Qno                                           Question  \
# 0     1  What is the primary benefit of Multi-AZ deploy...
# 1     2  Which AWS service allows you to run containers...
# 2     3  Which storage class is best for long-term arch...
# 3     4  Which service helps you centrally manage multi...
# 4     5       What is the main function of AWS CloudTrail?
# 5     6  Which architecture design improves resilience ...
# 6     7         What is the purpose of NAT Gateway in VPC?
# 7     8  Which AWS service provides infrastructure as c...
# 8     9  What is the benefit of Savings Plans over On-D...
# 9    10  Which AWS service is best suited for real-time...
# 10   11  What is the difference between IAM Role and IA...
# 11   12  Which AWS service detects security threats usi...
# 12   13       Which service protects against DDoS attacks?
# 13   14  Which VPC component controls subnet-level traf...
# 14   15                 What is the purpose of AWS Config?
# ...
