# %%
# Assignment 1
'''
# Create a directory
# Put a file inside that directory
# Write into file
# Read from file
# Delete written data inside that file
# Delete the directory
'''

import os
# Create a directory
os.mkdir('dir')

# Put a file inside that directory
os.chdir('dir')

# Write into file
with open('file.txt', 'w') as file:
    file.write("Assignment 1 of Day 3 focuses on directory management through Python")

# Read from file
with open('file.txt', 'r') as file:
    print(file.read())
    
# Delete written data inside that file
file = open('file.txt', 'w')
file.close()

with open('file.txt', 'r') as file:
    print(file.read())
    
# Delete the directory
os.chdir('..')

import shutil
shutil.rmtree('dir')
# Out:
# Assignment 1 of Day 3 focuses on directory management through Python
