# %%
'A'.isupper()
# Out:
# True

# %%
isinstance(['a','b'],str)
# Out:
# False

# %%
'c' > 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 'c' > 1
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
stri = (('abcd'))
len(stri)
# Out:
# 4
