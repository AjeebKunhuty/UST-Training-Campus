# %%
# !pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/455.4 MB 660.6 kB/s eta 0:11:30
#      ---------------------------------------- 0.2/455.4 MB 2.1 MB/s eta 0:03:40
#      ---------------------------------------- 0.6/455.4 MB 4.3 MB/s eta 0:01:47
#      ---------------------------------------- 1.1/455.4 MB 5.9 MB/s eta 0:01:17
#      ---------------------------------------- 1.8/455.4 MB 7.7 MB/s eta 0:01:00
#      ---------------------------------------- 2.7/455.4 MB 9.7 MB/s eta 0:00:47
#      --------------------------------------- 3.9/455.4 MB 11.8 MB/s eta 0:00:39
#      --------------------------------------- 5.4/455.4 MB 14.4 MB/s eta 0:00:32
#       -------------------------------------- 7.3/455.4 MB 17.3 MB/s eta 0:00:26
#       ------------------------------------- 10.0/455.4 MB 21.2 MB/s eta 0:00:22
# ...

# %%
import pyspark
dir(pyspark)
# Out:
# ['Accumulator',
#  'AccumulatorParam',
#  'Any',
#  'BarrierTaskContext',
#  'BarrierTaskInfo',
#  'BasicProfiler',
#  'Broadcast',
#  'CPickleSerializer',
#  'Callable',
#  'HiveContext',
#  'InheritableThread',
#  'MarshalSerializer',
#  'Profiler',
#  'RDD',
#  'RDDBarrier',
#  'Row',
#  'SQLContext',
#  'SparkConf',
#  'SparkContext',
#  'SparkFiles',
#  'SparkJobInfo',
#  'SparkStageInfo',
#  'StatusTracker',
#  'StorageLevel',
#  'TaskContext',
#  'TypeVar',
#  'Union',
#  '_F',
#  '_NoValue',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_globals',
#  'accumulators',
#  'broadcast',
#  'cast',
#  'cloudpickle',
#  'conf',
#  'context',
#  'core',
#  'errors',
#  'files',
#  'find_spark_home',
#  'inheritable_thread_target',
#  'is_remote_only',
#  'java_gateway',
#  'join',
#  'keyword_only',
#  'logger',
#  'loose_version',
#  'profiler',
# ...

# %%
# !pip install pyspark findspark
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("My PySpark App") \
    .getOrCreate()

df = spark.createDataFrame([("Alice", 1), ("Bob", 2)], ["Name", "Value"])
df.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       2 findspark.init()
#       4 from pyspark.sql import SparkSession
#       5 spark = SparkSession.builder \
#       6     .master("local[*]") \
#       7     .appName("My PySpark App") \
# ----> 8     .getOrCreate()
#      10 df = spark.createDataFrame([("Alice", 1), ("Bob", 2)], ["Name", "Value"])
#      11 df.show()
#
# File C:\Program Files\Python312\Lib\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# ...

# %%
spark.range(5).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 spark.range(5).show()
#
# NameError: name 'spark' is not defined
